# %%
import stanza

# %%
#Lemmatization for Bulgarian with uppercase


# Initialize the Bulgarian model for lemmatization
def ensure_bulgarian_model():
    try:
        print("Loading Bulgarian model...")
        nlp = stanza.Pipeline('bg', processors='tokenize,lemma', use_gpu=False)
        print("Bulgarian model loaded successfully.")
    except Exception as e:
        print(f"Error loading Bulgarian model: {e}")
        print("Attempting to download the Bulgarian model...")
        stanza.download('bg')
        nlp = stanza.Pipeline('bg', processors='tokenize,lemma', use_gpu=False)
    return nlp

def process_file(input_file, output_file):
    nlp = ensure_bulgarian_model()

    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:

        lines = infile.readlines()
        sentence = []
        current_sent_id = None

        for line in lines:
            stripped_line = line.strip()

            if stripped_line.startswith("# newdoc id"):
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
                outfile.write(f"{stripped_line}\n")
                current_sent_id = None

            elif stripped_line.startswith("# sent_id"):
                if current_sent_id is not None and stripped_line == current_sent_id:
                    continue
                else:
                    if sentence:
                        process_sentence(sentence, outfile)
                        sentence = []
                    current_sent_id = stripped_line
                    outfile.write(f"{current_sent_id}\n")

            elif stripped_line.startswith("# text"):
                sentence.append(stripped_line)
                outfile.write(f"{stripped_line}\n")

            elif stripped_line:
                token_data = stripped_line.split('\t')
                if len(token_data) == 3:
                    idx, token, tag = token_data
                    lemmatized_token = get_lemmatized_token_with_case(token, nlp)
                    outfile.write(f"{idx}\t{lemmatized_token}\t{tag}\n")
                else:
                    outfile.write(f"{stripped_line}\n")  # In case of unexpected format

            else:
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []

        if sentence:
            process_sentence(sentence, outfile)

def get_lemmatized_token_with_case(token, nlp):
    doc = nlp(token)
    original_word = token.strip()
    lemmatized_word = doc.sentences[0].words[0].lemma

    # Preserve case
    if original_word.istitle():
        return lemmatized_word.capitalize()
    elif original_word.isupper():
        return lemmatized_word.upper()
    else:
        return lemmatized_word.lower()

def process_sentence(sentence, outfile):
    outfile.write("\n\n")

# Input and output file paths
input_file_1 = "data/test/bg.txt"
input_file_2 = "data/train/bg.txt"
input_file_3 = "data/val/bg.txt"
output_file_1 = "data/test/lemmatized_bg.txt"
output_file_2 = "data/train/lemmatized_bg.txt"
output_file_3 = "data/val/lemmatized_bg.txt"
process_file(input_file_1, output_file_1)
process_file(input_file_2, output_file_2)
process_file(input_file_3, output_file_3)
# Out:
# 2025-04-24 16:30:51 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Bulgarian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 25.9MB/s]
# 2025-04-24 16:30:51 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 16:30:51 INFO: Loading these models for language: bg (Bulgarian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | btb          |
# | lemma     | btb_nocharlm |
# ============================
#
# 2025-04-24 16:30:51 INFO: Using device: cpu
# 2025-04-24 16:30:51 INFO: Loading: tokenize
# 2025-04-24 16:30:51 INFO: Loading: lemma
# 2025-04-24 16:30:52 INFO: Done loading processors!
# Bulgarian model loaded successfully.
# 2025-04-24 16:38:16 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Bulgarian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 28.4MB/s]
# 2025-04-24 16:38:17 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 16:38:17 INFO: Loading these models for language: bg (Bulgarian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | btb          |
# | lemma     | btb_nocharlm |
# ============================
#
# 2025-04-24 16:38:17 INFO: Using device: cpu
# 2025-04-24 16:38:17 INFO: Loading: tokenize
# 2025-04-24 16:38:17 INFO: Loading: lemma
# 2025-04-24 16:38:17 INFO: Done loading processors!
# Bulgarian model loaded successfully.
# 2025-04-24 17:00:24 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Bulgarian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 29.3MB/s]
# 2025-04-24 17:00:24 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 17:00:24 INFO: Loading these models for language: bg (Bulgarian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | btb          |
# | lemma     | btb_nocharlm |
# ============================
#
# 2025-04-24 17:00:24 INFO: Using device: cpu
# 2025-04-24 17:00:24 INFO: Loading: tokenize
# 2025-04-24 17:00:24 INFO: Loading: lemma
# 2025-04-24 17:00:25 INFO: Done loading processors!
# Bulgarian model loaded successfully.

# %%
# Lemmatization for Ukrainian with uppercase

# Initialize the Ukrainian model for lemmatization
def ensure_ukrainian_model():
    try:
        print("Loading Ukrainian model...")
        nlp = stanza.Pipeline('uk', processors='tokenize,lemma')  # Tokenization and Lemmatization
        print("Ukrainian model loaded successfully.")
    except Exception as e:
        print(f"Error loading Ukrainian model: {e}")
        print("Attempting to download the Ukrainian model...")
        stanza.download('uk')  # Download Ukrainian model if it's not present
        nlp = stanza.Pipeline('uk', processors='tokenize,lemma')
    return nlp

def process_file(input_file, output_file):
    nlp = ensure_ukrainian_model()
    
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
         
        lines = infile.readlines()
        sentence = []         # To collect sentence lines (mainly the # text line)
        current_sent_id = None  # Track the last sent_id written
        
        for line in lines:
            stripped_line = line.strip()
            
            if stripped_line.startswith("# newdoc id"):
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
                outfile.write(f"{stripped_line}\n")
                current_sent_id = None
                
            elif stripped_line.startswith("# sent_id"):
                if current_sent_id is not None and stripped_line == current_sent_id:
                    continue
                else:
                    if sentence:
                        process_sentence(sentence, outfile)
                        sentence = []
                    current_sent_id = stripped_line
                    outfile.write(f"{current_sent_id}\n")
                    
            elif stripped_line.startswith("# text"):
                sentence.append(stripped_line)
                outfile.write(f"{stripped_line}\n")
            
            # Updated section for tab-separated numbered format
            elif stripped_line:
                token_data = stripped_line.split('\t')
                if len(token_data) == 3:
                    idx, token, tag = token_data
                    lemmatized_token = get_lemmatized_token_with_case(token, nlp)
                    outfile.write(f"{idx}\t{lemmatized_token}\t{tag}\n")
                else:
                    outfile.write(f"{stripped_line}\n")  # fallback if unexpected format
            
            else:
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
        
        if sentence:
            process_sentence(sentence, outfile)

def get_lemmatized_token_with_case(token, nlp):
    doc = nlp(token)
    original_word = token.strip()
    lemmatized_word = doc.sentences[0].words[0].lemma
    
    if original_word.istitle():
        return lemmatized_word.capitalize()
    elif original_word.isupper():
        return lemmatized_word.upper()
    else:
        return lemmatized_word.lower()

def process_sentence(sentence, outfile):
    outfile.write("\n\n")

# File paths
input_file_1 = "data/test/uk.txt"
input_file_2 = "data/train/uk.txt"
input_file_3 = "data/val/uk.txt"
output_file_1 = "data/test/lemmatized_uk.txt"
output_file_2 = "data/train/lemmatized_uk.txt"
output_file_3 = "data/val/lemmatized_uk.txt"
process_file(input_file_1, output_file_1)
process_file(input_file_2, output_file_2)
process_file(input_file_3, output_file_3)
# Out:
# 2025-04-24 20:11:58 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Ukrainian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 85.3MB/s]
# 2025-04-24 20:11:59 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:11:59 WARNING: Language uk package default expects mwt, which has been added
# 2025-04-24 20:11:59 INFO: Loading these models for language: uk (Ukrainian):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | iu          |
# | mwt       | iu          |
# | lemma     | iu_nocharlm |
# ===========================
#
# 2025-04-24 20:11:59 INFO: Using device: cpu
# 2025-04-24 20:11:59 INFO: Loading: tokenize
# 2025-04-24 20:11:59 INFO: Loading: mwt
# 2025-04-24 20:11:59 INFO: Loading: lemma
# 2025-04-24 20:11:59 INFO: Done loading processors!
# Ukrainian model loaded successfully.
# 2025-04-24 20:14:16 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Ukrainian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 60.9MB/s]
# 2025-04-24 20:14:16 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:14:16 WARNING: Language uk package default expects mwt, which has been added
# 2025-04-24 20:14:16 INFO: Loading these models for language: uk (Ukrainian):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | iu          |
# | mwt       | iu          |
# | lemma     | iu_nocharlm |
# ===========================
#
# 2025-04-24 20:14:16 INFO: Using device: cpu
# 2025-04-24 20:14:16 INFO: Loading: tokenize
# 2025-04-24 20:14:16 INFO: Loading: mwt
# 2025-04-24 20:14:16 INFO: Loading: lemma
# 2025-04-24 20:14:17 INFO: Done loading processors!
# Ukrainian model loaded successfully.
# 2025-04-24 20:18:29 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Ukrainian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 60.9MB/s]
# 2025-04-24 20:18:29 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:18:29 WARNING: Language uk package default expects mwt, which has been added
# 2025-04-24 20:18:30 INFO: Loading these models for language: uk (Ukrainian):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | iu          |
# | mwt       | iu          |
# | lemma     | iu_nocharlm |
# ===========================
#
# 2025-04-24 20:18:30 INFO: Using device: cpu
# 2025-04-24 20:18:30 INFO: Loading: tokenize
# 2025-04-24 20:18:30 INFO: Loading: mwt
# 2025-04-24 20:18:30 INFO: Loading: lemma
# 2025-04-24 20:18:30 INFO: Done loading processors!
# Ukrainian model loaded successfully.

# %%
# Lemmatization for Russian with uppercase

# Initialize the Russian model for lemmatization
def ensure_russian_model():
    try:
        print("Loading Russian model...")
        nlp = stanza.Pipeline('ru', processors='tokenize,lemma')  # Tokenization and Lemmatization
        print("Russian model loaded successfully.")
    except Exception as e:
        print(f"Error loading Russian model: {e}")
        print("Attempting to download the Russian model...")
        stanza.download('ru')  # Download Russian model if it's not present
        nlp = stanza.Pipeline('ru', processors='tokenize,lemma')
    return nlp

def process_file(input_file, output_file):
    nlp = ensure_russian_model()
    
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
         
        lines = infile.readlines()
        sentence = []
        current_sent_id = None
        
        for line in lines:
            stripped_line = line.strip()
            if stripped_line.startswith("# newdoc id"):
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
                outfile.write(f"{stripped_line}\n")
                current_sent_id = None
                
            elif stripped_line.startswith("# sent_id"):
                if current_sent_id is not None and stripped_line == current_sent_id:
                    continue
                else:
                    if sentence:
                        process_sentence(sentence, outfile)
                        sentence = []
                    current_sent_id = stripped_line
                    outfile.write(f"{current_sent_id}\n")
                    
            elif stripped_line.startswith("# text"):
                sentence.append(stripped_line)
                outfile.write(f"{stripped_line}\n")
            
            elif stripped_line:
                token_data = stripped_line.split('\t')
                if len(token_data) == 3:
                    idx, token, tag = token_data
                    lemmatized_token = get_lemmatized_token_with_case(token, nlp)
                    outfile.write(f"{idx}\t{lemmatized_token}\t{tag}\n")
                else:
                    outfile.write(f"{stripped_line}\n")
            
            else:
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
        
        if sentence:
            process_sentence(sentence, outfile)

def get_lemmatized_token_with_case(token, nlp):
    doc = nlp(token)
    original_word = token.strip()
    lemmatized_word = doc.sentences[0].words[0].lemma
    
    if original_word.istitle():
        return lemmatized_word.capitalize()
    elif original_word.isupper():
        return lemmatized_word.upper()
    else:
        return lemmatized_word.lower()

def process_sentence(sentence, outfile):
    outfile.write("\n\n")

# File paths
input_file_1 = "data/test/ru.txt"
input_file_2 = "data/train/ru.txt"
input_file_3 = "data/val/ru.txt"
output_file_1 = "data/test/lemmatized_ru.txt"
output_file_2 = "data/train/lemmatized_ru.txt"
output_file_3 = "data/val/lemmatized_ru.txt"
process_file(input_file_1, output_file_1)
process_file(input_file_2, output_file_2)
process_file(input_file_3, output_file_3)
# Out:
# 2025-04-24 20:21:30 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Russian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 60.8MB/s]
# 2025-04-24 20:21:30 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:21:30 INFO: Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | lemma     | syntagrus_nocharlm |
# ==================================
#
# 2025-04-24 20:21:30 INFO: Using device: cpu
# 2025-04-24 20:21:30 INFO: Loading: tokenize
# 2025-04-24 20:21:30 INFO: Loading: lemma
# 2025-04-24 20:21:33 INFO: Done loading processors!
# Russian model loaded successfully.
# 2025-04-24 20:34:05 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Russian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 38.7MB/s]
# 2025-04-24 20:34:05 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:34:05 INFO: Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | lemma     | syntagrus_nocharlm |
# ==================================
#
# 2025-04-24 20:34:05 INFO: Using device: cpu
# 2025-04-24 20:34:05 INFO: Loading: tokenize
# 2025-04-24 20:34:05 INFO: Loading: lemma
# 2025-04-24 20:34:09 INFO: Done loading processors!
# Russian model loaded successfully.
# 2025-04-24 20:46:22 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Russian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 106MB/s]
# 2025-04-24 20:46:23 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 20:46:23 INFO: Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | lemma     | syntagrus_nocharlm |
# ==================================
#
# 2025-04-24 20:46:23 INFO: Using device: cpu
# 2025-04-24 20:46:23 INFO: Loading: tokenize
# 2025-04-24 20:46:23 INFO: Loading: lemma
# 2025-04-24 20:46:27 INFO: Done loading processors!
# Russian model loaded successfully.

# %%
# Lemmatization for Slovenian with uppercase

# Initialize the Slovenian model for lemmatization
def ensure_slovenian_model():
    try:
        print("Loading Slovenian model...")
        nlp = stanza.Pipeline('sl', processors='tokenize,lemma')  # Tokenization and Lemmatization
        print("Slovenian model loaded successfully.")
    except Exception as e:
        print(f"Error loading Slovenian model: {e}")
        print("Attempting to download the Slovenian model...")
        stanza.download('sl')  # Download Slovenian model if it's not present
        nlp = stanza.Pipeline('sl', processors='tokenize,lemma')
    return nlp

def process_file(input_file, output_file):
    nlp = ensure_slovenian_model()
    
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
         
        lines = infile.readlines()
        sentence = []
        current_sent_id = None
        
        for line in lines:
            stripped_line = line.strip()
            if stripped_line.startswith("# newdoc id"):
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
                outfile.write(f"{stripped_line}\n")
                current_sent_id = None
                
            elif stripped_line.startswith("# sent_id"):
                if current_sent_id is not None and stripped_line == current_sent_id:
                    continue
                else:
                    if sentence:
                        process_sentence(sentence, outfile)
                        sentence = []
                    current_sent_id = stripped_line
                    outfile.write(f"{current_sent_id}\n")
                    
            elif stripped_line.startswith("# text"):
                sentence.append(stripped_line)
                outfile.write(f"{stripped_line}\n")
            
            elif stripped_line:
                token_data = stripped_line.split('\t')
                if len(token_data) == 3:
                    idx, token, tag = token_data
                    lemmatized_token = get_lemmatized_token_with_case(token, nlp)
                    outfile.write(f"{idx}\t{lemmatized_token}\t{tag}\n")
                else:
                    outfile.write(f"{stripped_line}\n")
            
            else:
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
        
        if sentence:
            process_sentence(sentence, outfile)

def get_lemmatized_token_with_case(token, nlp):
    doc = nlp(token)
    original_word = token.strip()
    lemmatized_word = doc.sentences[0].words[0].lemma
    
    if original_word.istitle():
        return lemmatized_word.capitalize()
    elif original_word.isupper():
        return lemmatized_word.upper()
    else:
        return lemmatized_word.lower()

def process_sentence(sentence, outfile):
    outfile.write("\n\n")

# File paths
input_file_1 = "data/test/sl.txt"
input_file_2 = "data/train/sl.txt"
input_file_3 = "data/val/sl.txt"
output_file_1 = "data/test/lemmatized_sl.txt"
output_file_2 = "data/train/lemmatized_sl.txt"
output_file_3 = "data/val/lemmatized_sl.txt"
process_file(input_file_1, output_file_1)
process_file(input_file_2, output_file_2)
process_file(input_file_3, output_file_3)
# Out:
# 2025-04-24 15:45:05 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Slovenian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 33.9MB/s]
# 2025-04-24 15:45:05 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 15:45:05 INFO: Loading these models for language: sl (Slovenian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ssj          |
# | lemma     | ssj_nocharlm |
# ============================
#
# 2025-04-24 15:45:05 INFO: Using device: cpu
# 2025-04-24 15:45:05 INFO: Loading: tokenize
# 2025-04-24 15:45:05 INFO: Loading: lemma
# 2025-04-24 15:45:06 INFO: Done loading processors!
# Slovenian model loaded successfully.
# 2025-04-24 15:55:56 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Slovenian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 30.7MB/s]
# 2025-04-24 15:55:56 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 15:55:56 INFO: Loading these models for language: sl (Slovenian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ssj          |
# | lemma     | ssj_nocharlm |
# ============================
#
# 2025-04-24 15:55:56 INFO: Using device: cpu
# 2025-04-24 15:55:56 INFO: Loading: tokenize
# 2025-04-24 15:55:56 INFO: Loading: lemma
# 2025-04-24 15:55:57 INFO: Done loading processors!
# Slovenian model loaded successfully.
# 2025-04-24 16:16:12 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Slovenian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 29.7MB/s]
# 2025-04-24 16:16:17 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-24 16:16:17 INFO: Loading these models for language: sl (Slovenian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ssj          |
# | lemma     | ssj_nocharlm |
# ============================
#
# 2025-04-24 16:16:17 INFO: Using device: cpu
# 2025-04-24 16:16:17 INFO: Loading: tokenize
# 2025-04-24 16:16:17 INFO: Loading: lemma
# 2025-04-24 16:16:19 INFO: Done loading processors!
# Slovenian model loaded successfully.

# %%
#working version without uppercase
import stanza

# Initialize the Bulgarian model for lemmatization
def ensure_bulgarian_model():
    try:
        print("Loading Bulgarian model...")
        nlp = stanza.Pipeline('bg', processors='tokenize,lemma')  # Tokenization and Lemmatization
        print("Bulgarian model loaded successfully.")
    except Exception as e:
        print(f"Error loading Bulgarian model: {e}")
        print("Attempting to download the Bulgarian model...")
        stanza.download('bg')  # Download Bulgarian model if it's not present
        nlp = stanza.Pipeline('bg', processors='tokenize,lemma')
    return nlp

def process_file(input_file, output_file):
    nlp = ensure_bulgarian_model()
    
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
         
        lines = infile.readlines()
        sentence = []         # To collect sentence lines (here mainly the # text line)
        current_sent_id = None  # Track the last sent_id written
        
        for line in lines:
            stripped_line = line.strip()
            # New document: simply output and reset
            if stripped_line.startswith("# newdoc id"):
                # Process any pending sentence (if applicable)
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
                outfile.write(f"{stripped_line}\n")
                current_sent_id = None  # reset for new document
                
            # Sentence ID line
            elif stripped_line.startswith("# sent_id"):
                # Check if this sent_id is a duplicate of the one we already wrote.
                if current_sent_id is not None and stripped_line == current_sent_id:
                    # Skip duplicate sent_id
                    continue
                else:
                    if sentence:
                        # End previous sentence block by processing it.
                        process_sentence(sentence, outfile)
                        sentence = []
                    current_sent_id = stripped_line
                    outfile.write(f"{current_sent_id}\n")
                    
            # Text field line: process with lemmatizer and write updated text
            elif stripped_line.startswith("# text"):
                # Store the text line in our sentence collection (if needed)
                sentence.append(stripped_line)
                # Extract the actual text and lemmatize it.
                text = stripped_line.split("=", 1)[-1].strip()
                lemmatized_text = lemmatize_sentence(text, nlp)
                outfile.write(f"# text = {lemmatized_text}\n")
            
            # Token lines (word and tag)
            elif stripped_line:
                token_data = stripped_line.split()
                if len(token_data) == 2:
                    token, tag = token_data
                    lemmatized_token = get_lemmatized_token(token, nlp)
                    outfile.write(f"{lemmatized_token} {tag}\n")
            
            # Blank line indicates end of a sentence block
            else:
                if sentence:
                    process_sentence(sentence, outfile)
                    sentence = []
        
        # Process any remaining sentence block at the end.
        if sentence:
            process_sentence(sentence, outfile)

def lemmatize_sentence(text, nlp):
    doc = nlp(text)
    lemmatized_words = [word.lemma for sent in doc.sentences for word in sent.words]
    return " ".join(lemmatized_words)

def get_lemmatized_token(token, nlp):
    doc = nlp(token)
    return doc.sentences[0].words[0].lemma

def process_sentence(sentence, outfile):
    """
    This function is called at the end of a sentence block (when a blank line is encountered
    or before starting a new sentence). Instead of re-writing any collected metadata (like sent_id or # text)
    it simply writes two newlines.
    """
    outfile.write("\n\n")

# Input and output file paths
input_file = "bg.txt"
output_file = "updated_bg.txt"

process_file(input_file, output_file)
# Out:
# 2025-04-10 17:38:36 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Loading Bulgarian model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 424kB [00:00, 33.3MB/s]
# 2025-04-10 17:38:36 INFO: Downloaded file to C:\Users\mihae\stanza_resources\resources.json
# 2025-04-10 17:38:36 INFO: Loading these models for language: bg (Bulgarian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | btb          |
# | lemma     | btb_nocharlm |
# ============================
#
# 2025-04-10 17:38:36 INFO: Using device: cpu
# 2025-04-10 17:38:36 INFO: Loading: tokenize
# 2025-04-10 17:38:36 INFO: Loading: lemma
# 2025-04-10 17:38:36 INFO: Done loading processors!
# Bulgarian model loaded successfully.
